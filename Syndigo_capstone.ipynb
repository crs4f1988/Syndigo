# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
PFG = pd.read_csv("./Data/PFG.csv")

# %%
PFG
# Out:
#                                PublicationID  \
# 0       00006955-e01d-4478-91c9-5465e7b34754
# 1       00006955-e01d-4478-91c9-5465e7b34754
# 2       00006955-e01d-4478-91c9-5465e7b34754
# 3       00008d97-73d0-4724-972c-f074040ccba2
# 4       00008d97-73d0-4724-972c-f074040ccba2
# ...                                      ...
# 424614  ffffb3c9-f738-4510-9d9f-7f762e7a3435
# 424615  ffffb3c9-f738-4510-9d9f-7f762e7a3435
# 424616  ffffb3c9-f738-4510-9d9f-7f762e7a3435
# 424617  ffffe910-6ef4-4944-947e-304389f52e20
# 424618  ffffee69-c80a-4332-97b8-8cdcab703baa
#
#                                  Party_Name        Product_Type          GTIN  \
# 0                             CLIF BAR INC.                CASE  7.222522e+11
# 1                             CLIF BAR INC.  PACK_OR_INNER_PACK  7.222522e+11
# 2                             CLIF BAR INC.   BASE_UNIT_OR_EACH  7.222522e+11
# 3             Carlisle Foodservice Products   BASE_UNIT_OR_EACH  7.783887e+10
# ...

# %%
Renzi = pd.read_csv("./Data/Renzi.csv")

# %%
Renzi
# Out:
#                                PublicationID              Party_Name  \
# 0       00001a82-4bc6-43dd-b846-6b2e1bb75b97  UniPro Foodservice Inc
# 1       0000451a-717c-4a79-9b9e-85f7c62fdb77  UniPro Foodservice Inc
# 2       0000451a-717c-4a79-9b9e-85f7c62fdb77  UniPro Foodservice Inc
# 3       000048b8-9ced-44bc-8d70-cc77fcdfcc82  UniPro Foodservice Inc
# 4       00005436-ff85-47ee-bdf0-4a21b46d5518  UniPro Foodservice Inc
# ...                                      ...                     ...
# 446974  d463c394-6766-4880-844f-0db40d82bdff  UniPro Foodservice Inc
# 446975  d463c394-6766-4880-844f-0db40d82bdff  UniPro Foodservice Inc
# 446976  d463d109-140c-4c71-8d70-01b9ae501b1f  UniPro Foodservice Inc
# 446977  d463dfc8-2b03-4a2e-b5a0-6afc006aaeab          Dot Foods Inc.
# 446978  d4641ce1-ea0f-4c11-b8e7-7ead0067ac2d  UniPro Foodservice Inc
#
#              Product_Type          GTIN                MPC  \
# 0       BASE_UNIT_OR_EACH  1.380072e+10  00013800716774USL
# ...

# %%
GCFoods = pd.read_csv("./Data/GCFoods.csv")

# %%
GCFoods
# Out:
#                                PublicationID              Party_Name  \
# 0       00002964-40c0-4ca4-83b5-8e3d8a2994ba  UniPro Foodservice Inc
# 1       00002af0-3561-4f5b-8d19-fc21dedaa094  UniPro Foodservice Inc
# 2       0000752e-4b04-4098-9876-94db2d5b8a52  UniPro Foodservice Inc
# 3       0000752e-4b04-4098-9876-94db2d5b8a52  UniPro Foodservice Inc
# 4       00007cda-0685-4027-b66b-5d91221960a3  UniPro Foodservice Inc
# ...                                      ...                     ...
# 385293  fffed50c-b312-4de8-90d9-48bc39370c06  UniPro Foodservice Inc
# 385294  fffed97f-dedd-4bd8-9d36-20d7073aa5d5  UniPro Foodservice Inc
# 385295  fffed97f-dedd-4bd8-9d36-20d7073aa5d5  UniPro Foodservice Inc
# 385296  fffed97f-dedd-4bd8-9d36-20d7073aa5d5  UniPro Foodservice Inc
# 385297  ffffb5c9-4c00-4ac1-a630-bf465152992e  UniPro Foodservice Inc
#
#               Product_Type  Quantity          GTIN    ParentGTIN  \
# 0        BASE_UNIT_OR_EACH       NaN  6.870803e+11           NaN
# ...
